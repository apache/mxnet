# %%
import wget
import argparse
import mxnet as mx
import os
import sys

# %%
sys.path.append(os.path.join(os.getcwd()))
sys.path.append(os.path.join(os.getcwd(),'dataset'))
sys.path.append(os.path.join(os.getcwd(),'train'))


from train.train_net import train_net

# %%
def default_parser():
    parser = argparse.ArgumentParser(description='Train a Single-shot detection network')
    parser.add_argument('--dataset', dest='dataset', help='which dataset to use',
                        default='pascal', type=str)
    parser.add_argument('--image-set', dest='image_set', help='train set, can be trainval or train',
                        default='trainval', type=str)
    parser.add_argument('--year', dest='year', help='can be 2007, 2012',
                        default='2007,2012', type=str)
    parser.add_argument('--val-image-set', dest='val_image_set', help='validation set, can be val or test',
                        default='test', type=str)
    parser.add_argument('--val-year', dest='val_year', help='can be 2007, 2010, 2012',
                        default='2007', type=str)
    parser.add_argument('--devkit-path', dest='devkit_path', help='VOCdevkit path',
                        default=os.path.join(os.getcwd(), 'data', 'VOCdevkit'), type=str)
    parser.add_argument('--network', dest='network', type=str, default='vgg16_reduced',
                        choices=['vgg16_reduced'], help='which network to use')
    parser.add_argument('--batch-size', dest='batch_size', type=int, default=32,
                        help='training batch size')
    parser.add_argument('--resume', dest='resume', type=int, default=-1,
                        help='resume training from epoch n')
    parser.add_argument('--finetune', dest='finetune', type=int, default=-1,
                        help='finetune from epoch n, rename the model before doing this')
    parser.add_argument('--pretrained', dest='pretrained', help='pretrained model prefix',
                        default=os.path.join(os.getcwd(), 'model', 'vgg16_reduced'), type=str)
    parser.add_argument('--epoch', dest='epoch', help='epoch of pretrained model',
                        default=1, type=int)
    parser.add_argument('--prefix', dest='prefix', help='new model prefix',
                        default=os.path.join(os.getcwd(), 'model', 'ssd_train'), type=str)
    parser.add_argument('--gpus', dest='gpus', help='GPU devices to train with',
                        default='0', type=str)
    parser.add_argument('--begin-epoch', dest='begin_epoch', help='begin epoch of training',
                        default=0, type=int)
    parser.add_argument('--end-epoch', dest='end_epoch', help='end epoch of training',
                        default=100, type=int)
    parser.add_argument('--frequent', dest='frequent', help='frequency of logging',
                        default=10, type=int)
    parser.add_argument('--data-shape', dest='data_shape', type=int, default=300,
                        help='set image shape')
    parser.add_argument('--lr', dest='learning_rate', type=float, default=0.001,
                        help='learning rate')
    parser.add_argument('--momentum', dest='momentum', type=float, default=0.9,
                        help='momentum')
    parser.add_argument('--wd', dest='weight_decay', type=float, default=0.0001,
                        help='weight decay')
    parser.add_argument('--mean-r', dest='mean_r', type=float, default=123,
                        help='red mean value')
    parser.add_argument('--mean-g', dest='mean_g', type=float, default=117,
                        help='green mean value')
    parser.add_argument('--mean-b', dest='mean_b', type=float, default=104,
                        help='blue mean value')
    parser.add_argument('--lr-epoch', dest='lr_refactor_epoch', type=int, default=50,
                        help='refactor learning rate every N epoch')
    parser.add_argument('--lr-ratio', dest='lr_refactor_ratio', type=float, default=0.9,
                        help='ratio to refactor learning rate')
    parser.add_argument('--log', dest='log_file', type=str, default="ssd_train.log",
                        help='save training log to file')
    parser.add_argument('--monitor', dest='monitor', type=int, default=10,
                        help='log network parameters every N iters if larger than 0')
    return parser

# %%
args =default_parser().parse_args(args='')

# %%
ctx = [mx.gpu(int(i)) for i in args.gpus.split(',')]
ctx = mx.cpu() if not ctx else ctx
ctx = [mx.cpu(0),mx.cpu(2),mx.cpu(1),mx.cpu(3)]
train_net(args.network, args.dataset, args.image_set, args.year,
          args.devkit_path, args.batch_size,
          args.data_shape, [args.mean_r, args.mean_g, args.mean_b],
          args.resume, args.finetune, args.pretrained,
          args.epoch, args.prefix, ctx, args.begin_epoch, args.end_epoch,
          args.frequent, args.learning_rate, args.momentum, args.weight_decay,
          args.val_image_set, args.val_year, args.lr_refactor_epoch,
          args.lr_refactor_ratio, args.monitor, args.log_file)
# Out:
# INFO:root:Start training with (cpu(0),cpu(2),cpu(1),cpu(3)) from pretrained model /Users/imry/github_code/mxnet/example/ssd/model/vgg16_reduced
# INFO:root:Freezed parameters: [conv1_1_weight,conv1_1_bias,conv1_2_weight,conv1_2_bias,conv2_1_weight,conv2_1_bias,conv2_2_weight,conv2_2_bias]
# [('data', (32, 3, 300, 300))]
# [('label', (32, 56, 5))]
# %%%%%%%%%%%%%%%%%%%%%% ITER Data Loaded %%%%%%%%%%%%%%%%%%%
# INFO:root:Batch:       1 conv1_1_output                 57.7534
# INFO:root:Batch:       1 relu1_1_output                 41.1074
# INFO:root:Batch:       1 conv1_2_output                 199.377
# INFO:root:Batch:       1 relu1_2_output                 178.258
# INFO:root:Batch:       1 pool1_output                   217.33
# INFO:root:Batch:       1 conv2_1_output                 384.246
# INFO:root:Batch:       1 relu2_1_output                 273.348
# INFO:root:Batch:       1 conv2_2_output                 603.838
# INFO:root:Batch:       1 relu2_2_output                 400.015
# INFO:root:Batch:       1 pool2_output                   562.414
# INFO:root:Batch:       1 conv3_1_output                 769.924
# INFO:root:Batch:       1 relu3_1_output                 472.574
# INFO:root:Batch:       1 conv3_2_output                 818.008
# INFO:root:Batch:       1 relu3_2_output                 488.409
# INFO:root:Batch:       1 conv3_3_output                 822.63
# INFO:root:Batch:       1 relu3_3_output                 438.899
# INFO:root:Batch:       1 pool3_output                   624.284
# INFO:root:Batch:       1 conv4_1_output                 787.701
# INFO:root:Batch:       1 relu4_1_output                 332.728
# INFO:root:Batch:       1 conv4_2_output                 530.331
# INFO:root:Batch:       1 relu4_2_output                 199.14
# INFO:root:Batch:       1 conv4_3_output                 370.783
# INFO:root:Batch:       1 relu4_3_output                 79.9273
# INFO:root:Batch:       1 relu4_3_norm_output            0.0441941
# INFO:root:Batch:       1 relu4_3_norm_norm              1808.56
# INFO:root:Batch:       1 broadcast_mul0_0               0.0441941
# INFO:root:Batch:       1 _mulscalar0_0                  0.883882
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_output   0.670142
# INFO:root:Batch:       1 transpose1_0                   0.670142
# INFO:root:Batch:       1 flatten1_0                     0.670142
# INFO:root:Batch:       1 pool4_output                   121.812
# INFO:root:Batch:       1 conv5_1_output                 182.596
# INFO:root:Batch:       1 relu5_1_output                 58.9617
# INFO:root:Batch:       1 conv5_2_output                 95.6556
# INFO:root:Batch:       1 relu5_2_output                 27.6222
# INFO:root:Batch:       1 conv5_3_output                 59.8345
# INFO:root:Batch:       1 relu5_3_output                 7.23163
# INFO:root:Batch:       1 pool5_output                   13.321
# INFO:root:Batch:       1 conv6_output                   5.27079
# INFO:root:Batch:       1 relu6_output                   3.76468
# INFO:root:Batch:       1 conv7_output                   2.17165
# INFO:root:Batch:       1 relu7_output                   1.48676
# INFO:root:Batch:       1 relu7_cls_pred_conv_output     1.14843
# INFO:root:Batch:       1 transpose3_0                   1.14843
# INFO:root:Batch:       1 flatten4_0                     1.14843
# INFO:root:Batch:       1 conv8_1_output                 1.06364
# INFO:root:Batch:       1 relu8_1_output                 0.749494
# INFO:root:Batch:       1 conv8_2_output                 0.336582
# INFO:root:Batch:       1 relu8_2_output                 0.234699
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_output   0.15936
# INFO:root:Batch:       1 transpose5_0                   0.15936
# INFO:root:Batch:       1 flatten7_0                     0.15936
# INFO:root:Batch:       1 conv9_1_output                 0.17463
# INFO:root:Batch:       1 relu9_1_output                 0.123122
# INFO:root:Batch:       1 conv9_2_output                 0.057914
# INFO:root:Batch:       1 relu9_2_output                 0.0391146
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_output   0.0217624
# INFO:root:Batch:       1 transpose7_0                   0.0217624
# INFO:root:Batch:       1 flatten10_0                    0.0217624
# INFO:root:Batch:       1 conv10_1_output                0.0233624
# INFO:root:Batch:       1 relu10_1_output                0.017549
# INFO:root:Batch:       1 conv10_2_output                0.00676714
# INFO:root:Batch:       1 relu10_2_output                0.00480514
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_output  0.00262958
# INFO:root:Batch:       1 transpose9_0                   0.00262958
# INFO:root:Batch:       1 flatten13_0                    0.00262958
# INFO:root:Batch:       1 pool10_output                  0.00368771
# INFO:root:Batch:       1 pool10_cls_pred_conv_output    0.000779627
# INFO:root:Batch:       1 transpose11_0                  0.000779627
# INFO:root:Batch:       1 flatten16_0                    0.000779627
# INFO:root:Batch:       1 concat0_output                 0.811913
# INFO:root:Batch:       1 reshape0_0                     0.811913
# INFO:root:Batch:       1 multibox_cls_pred_0            0.811913
# INFO:root:Batch:       1 relu4_3_anchors_output         0.578537
# INFO:root:Batch:       1 flatten2_0                     0.578537
# INFO:root:Batch:       1 relu7_anchors_output           0.582957
# INFO:root:Batch:       1 flatten5_0                     0.582957
# INFO:root:Batch:       1 relu8_2_anchors_output         0.594703
# INFO:root:Batch:       1 flatten8_0                     0.594703
# INFO:root:Batch:       1 relu9_2_anchors_output         0.610375
# INFO:root:Batch:       1 flatten11_0                    0.610375
# INFO:root:Batch:       1 relu10_2_anchors_output        0.627113
# INFO:root:Batch:       1 flatten14_0                    0.627113
# INFO:root:Batch:       1 pool10_anchors_output          0.663065
# INFO:root:Batch:       1 flatten17_0                    0.663065
# INFO:root:Batch:       1 concat1_output                 0.582306
# INFO:root:Batch:       1 multibox_anchors_0             0.582306
# INFO:root:Batch:       1 multibox_target_loc_target     0.00945697
# INFO:root:Batch:       1 multibox_target_loc_mask       0.0149117
# INFO:root:Batch:       1 multibox_target_cls_target     0.16251
# INFO:root:Batch:       1 cls_prob_output                0.0632733
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_output   0.6983
# INFO:root:Batch:       1 transpose0_0                   0.6983
# INFO:root:Batch:       1 flatten0_0                     0.6983
# INFO:root:Batch:       1 relu7_loc_pred_conv_output     1.26366
# INFO:root:Batch:       1 transpose2_0                   1.26366
# INFO:root:Batch:       1 flatten3_0                     1.26366
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_output   0.174052
# INFO:root:Batch:       1 transpose4_0                   0.174052
# INFO:root:Batch:       1 flatten6_0                     0.174052
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_output   0.0261414
# INFO:root:Batch:       1 transpose6_0                   0.0261414
# INFO:root:Batch:       1 flatten9_0                     0.0261414
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_output  0.00312416
# INFO:root:Batch:       1 transpose8_0                   0.00312416
# INFO:root:Batch:       1 flatten12_0                    0.00312416
# INFO:root:Batch:       1 pool10_loc_pred_conv_output    0.00105019
# INFO:root:Batch:       1 transpose10_0                  0.00105019
# INFO:root:Batch:       1 flatten15_0                    0.00105019
# INFO:root:Batch:       1 multibox_loc_pred_output       0.874548
# INFO:root:Batch:       1 _minus0_0                      0.874601
# INFO:root:Batch:       1 _mul0_0                        0.0122286
# INFO:root:Batch:       1 loc_loss__0                    0.00777206
# INFO:root:Batch:       1 loc_loss_output                0.00777206
# INFO:root:Batch:       1 cls_label_output               0.16251
# INFO:root:Batch:       1 conv1_1_output                 52.3879
# INFO:root:Batch:       1 relu1_1_output                 37.7456
# INFO:root:Batch:       1 conv1_2_output                 185.581
# INFO:root:Batch:       1 relu1_2_output                 167.37
# INFO:root:Batch:       1 pool1_output                   197.339
# INFO:root:Batch:       1 conv2_1_output                 343.481
# INFO:root:Batch:       1 relu2_1_output                 244.452
# INFO:root:Batch:       1 conv2_2_output                 547.743
# INFO:root:Batch:       1 relu2_2_output                 362.671
# INFO:root:Batch:       1 pool2_output                   504.932
# INFO:root:Batch:       1 conv3_1_output                 675.648
# INFO:root:Batch:       1 relu3_1_output                 426.921
# INFO:root:Batch:       1 conv3_2_output                 718.906
# INFO:root:Batch:       1 relu3_2_output                 439.661
# INFO:root:Batch:       1 conv3_3_output                 745.698
# INFO:root:Batch:       1 relu3_3_output                 389.149
# INFO:root:Batch:       1 pool3_output                   556.622
# INFO:root:Batch:       1 conv4_1_output                 692.737
# INFO:root:Batch:       1 relu4_1_output                 294.933
# INFO:root:Batch:       1 conv4_2_output                 476.115
# INFO:root:Batch:       1 relu4_2_output                 171.825
# INFO:root:Batch:       1 conv4_3_output                 327.531
# INFO:root:Batch:       1 relu4_3_output                 64.7379
# INFO:root:Batch:       1 relu4_3_norm_output            0.0441941
# INFO:root:Batch:       1 relu4_3_norm_norm              1464.86
# INFO:root:Batch:       1 broadcast_mul0_0               0.0441941
# INFO:root:Batch:       1 _mulscalar0_0                  0.883882
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_output   0.667908
# INFO:root:Batch:       1 transpose1_0                   0.667908
# INFO:root:Batch:       1 flatten1_0                     0.667908
# INFO:root:Batch:       1 pool4_output                   98.3947
# INFO:root:Batch:       1 conv5_1_output                 146.42
# INFO:root:Batch:       1 relu5_1_output                 46.7055
# INFO:root:Batch:       1 conv5_2_output                 78.2998
# INFO:root:Batch:       1 relu5_2_output                 20.7508
# INFO:root:Batch:       1 conv5_3_output                 46.4449
# INFO:root:Batch:       1 relu5_3_output                 5.21274
# INFO:root:Batch:       1 pool5_output                   9.62275
# INFO:root:Batch:       1 conv6_output                   3.76934
# INFO:root:Batch:       1 relu6_output                   2.6862
# INFO:root:Batch:       1 conv7_output                   1.55222
# INFO:root:Batch:       1 relu7_output                   1.06152
# INFO:root:Batch:       1 relu7_cls_pred_conv_output     0.817798
# INFO:root:Batch:       1 transpose3_0                   0.817798
# INFO:root:Batch:       1 flatten4_0                     0.817798
# INFO:root:Batch:       1 conv8_1_output                 0.762459
# INFO:root:Batch:       1 relu8_1_output                 0.531534
# INFO:root:Batch:       1 conv8_2_output                 0.237857
# INFO:root:Batch:       1 relu8_2_output                 0.166371
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_output   0.111288
# INFO:root:Batch:       1 transpose5_0                   0.111288
# INFO:root:Batch:       1 flatten7_0                     0.111288
# INFO:root:Batch:       1 conv9_1_output                 0.123822
# INFO:root:Batch:       1 relu9_1_output                 0.0875607
# INFO:root:Batch:       1 conv9_2_output                 0.0408873
# INFO:root:Batch:       1 relu9_2_output                 0.027762
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_output   0.0155791
# INFO:root:Batch:       1 transpose7_0                   0.0155791
# INFO:root:Batch:       1 flatten10_0                    0.0155791
# INFO:root:Batch:       1 conv10_1_output                0.0165874
# INFO:root:Batch:       1 relu10_1_output                0.0124796
# INFO:root:Batch:       1 conv10_2_output                0.0048316
# INFO:root:Batch:       1 relu10_2_output                0.00341313
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_output  0.0018711
# INFO:root:Batch:       1 transpose9_0                   0.0018711
# INFO:root:Batch:       1 flatten13_0                    0.0018711
# INFO:root:Batch:       1 pool10_output                  0.00255762
# INFO:root:Batch:       1 pool10_cls_pred_conv_output    0.000549804
# INFO:root:Batch:       1 transpose11_0                  0.000549804
# INFO:root:Batch:       1 flatten16_0                    0.000549804
# INFO:root:Batch:       1 concat0_output                 0.680939
# INFO:root:Batch:       1 reshape0_0                     0.680939
# INFO:root:Batch:       1 multibox_cls_pred_0            0.68094
# INFO:root:Batch:       1 relu4_3_anchors_output         0.578537
# INFO:root:Batch:       1 flatten2_0                     0.578537
# INFO:root:Batch:       1 relu7_anchors_output           0.582957
# INFO:root:Batch:       1 flatten5_0                     0.582957
# INFO:root:Batch:       1 relu8_2_anchors_output         0.594703
# INFO:root:Batch:       1 flatten8_0                     0.594703
# INFO:root:Batch:       1 relu9_2_anchors_output         0.610375
# INFO:root:Batch:       1 flatten11_0                    0.610375
# INFO:root:Batch:       1 relu10_2_anchors_output        0.627113
# INFO:root:Batch:       1 flatten14_0                    0.627113
# INFO:root:Batch:       1 pool10_anchors_output          0.663065
# INFO:root:Batch:       1 flatten17_0                    0.663065
# INFO:root:Batch:       1 concat1_output                 0.582306
# INFO:root:Batch:       1 multibox_anchors_0             0.582306
# INFO:root:Batch:       1 multibox_target_loc_target     0.0147113
# INFO:root:Batch:       1 multibox_target_loc_mask       0.0154746
# INFO:root:Batch:       1 multibox_target_cls_target     0.226978
# INFO:root:Batch:       1 cls_prob_output                0.0591455
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_output   0.721352
# INFO:root:Batch:       1 transpose0_0                   0.721352
# INFO:root:Batch:       1 flatten0_0                     0.721352
# INFO:root:Batch:       1 relu7_loc_pred_conv_output     0.89191
# INFO:root:Batch:       1 transpose2_0                   0.89191
# INFO:root:Batch:       1 flatten3_0                     0.89191
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_output   0.122721
# INFO:root:Batch:       1 transpose4_0                   0.122721
# INFO:root:Batch:       1 flatten6_0                     0.122721
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_output   0.0189166
# INFO:root:Batch:       1 transpose6_0                   0.0189166
# INFO:root:Batch:       1 flatten9_0                     0.0189166
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_output  0.00220503
# INFO:root:Batch:       1 transpose8_0                   0.00220503
# INFO:root:Batch:       1 flatten12_0                    0.00220503
# INFO:root:Batch:       1 pool10_loc_pred_conv_output    0.000737417
# INFO:root:Batch:       1 transpose10_0                  0.000737417
# INFO:root:Batch:       1 flatten15_0                    0.000737417
# INFO:root:Batch:       1 multibox_loc_pred_output       0.73856
# INFO:root:Batch:       1 _minus0_0                      0.738695
# INFO:root:Batch:       1 _mul0_0                        0.0160224
# INFO:root:Batch:       1 loc_loss__0                    0.0115366
# INFO:root:Batch:       1 loc_loss_output                0.0115366
# INFO:root:Batch:       1 cls_label_output               0.226978
# INFO:root:Batch:       1 conv1_1_output                 60.0943
# INFO:root:Batch:       1 relu1_1_output                 43.1045
# INFO:root:Batch:       1 conv1_2_output                 215.078
# INFO:root:Batch:       1 relu1_2_output                 194.585
# INFO:root:Batch:       1 pool1_output                   228.97
# INFO:root:Batch:       1 conv2_1_output                 387.611
# INFO:root:Batch:       1 relu2_1_output                 276.232
# INFO:root:Batch:       1 conv2_2_output                 612.02
# INFO:root:Batch:       1 relu2_2_output                 411.939
# INFO:root:Batch:       1 pool2_output                   576.737
# INFO:root:Batch:       1 conv3_1_output                 782.403
# INFO:root:Batch:       1 relu3_1_output                 494.1
# INFO:root:Batch:       1 conv3_2_output                 851.39
# INFO:root:Batch:       1 relu3_2_output                 508.884
# INFO:root:Batch:       1 conv3_3_output                 848.139
# INFO:root:Batch:       1 relu3_3_output                 454.744
# INFO:root:Batch:       1 pool3_output                   654.786
# INFO:root:Batch:       1 conv4_1_output                 826.221
# INFO:root:Batch:       1 relu4_1_output                 346.602
# INFO:root:Batch:       1 conv4_2_output                 559.13
# INFO:root:Batch:       1 relu4_2_output                 206.553
# INFO:root:Batch:       1 conv4_3_output                 382.908
# INFO:root:Batch:       1 relu4_3_output                 81.8431
# INFO:root:Batch:       1 relu4_3_norm_output            0.0441941
# INFO:root:Batch:       1 relu4_3_norm_norm              1851.9
# INFO:root:Batch:       1 broadcast_mul0_0               0.0441941
# INFO:root:Batch:       1 _mulscalar0_0                  0.883882
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_output   0.665644
# INFO:root:Batch:       1 transpose1_0                   0.665644
# INFO:root:Batch:       1 flatten1_0                     0.665644
# INFO:root:Batch:       1 pool4_output                   125.892
# INFO:root:Batch:       1 conv5_1_output                 187.484
# INFO:root:Batch:       1 relu5_1_output                 61.1357
# INFO:root:Batch:       1 conv5_2_output                 101.019
# INFO:root:Batch:       1 relu5_2_output                 27.1732
# INFO:root:Batch:       1 conv5_3_output                 63.5756
# INFO:root:Batch:       1 relu5_3_output                 5.86594
# INFO:root:Batch:       1 pool5_output                   11.0378
# INFO:root:Batch:       1 conv6_output                   4.27413
# INFO:root:Batch:       1 relu6_output                   3.04561
# INFO:root:Batch:       1 conv7_output                   1.75184
# INFO:root:Batch:       1 relu7_output                   1.19403
# INFO:root:Batch:       1 relu7_cls_pred_conv_output     0.902499
# INFO:root:Batch:       1 transpose3_0                   0.902499
# INFO:root:Batch:       1 flatten4_0                     0.902499
# INFO:root:Batch:       1 conv8_1_output                 0.859257
# INFO:root:Batch:       1 relu8_1_output                 0.599129
# INFO:root:Batch:       1 conv8_2_output                 0.268726
# INFO:root:Batch:       1 relu8_2_output                 0.187358
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_output   0.125066
# INFO:root:Batch:       1 transpose5_0                   0.125066
# INFO:root:Batch:       1 flatten7_0                     0.125066
# INFO:root:Batch:       1 conv9_1_output                 0.138908
# INFO:root:Batch:       1 relu9_1_output                 0.0973923
# INFO:root:Batch:       1 conv9_2_output                 0.0454899
# INFO:root:Batch:       1 relu9_2_output                 0.0307528
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_output   0.0172559
# INFO:root:Batch:       1 transpose7_0                   0.0172559
# INFO:root:Batch:       1 flatten10_0                    0.0172559
# INFO:root:Batch:       1 conv10_1_output                0.0185671
# INFO:root:Batch:       1 relu10_1_output                0.0138661
# INFO:root:Batch:       1 conv10_2_output                0.00527709
# INFO:root:Batch:       1 relu10_2_output                0.00372788
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_output  0.00201192
# INFO:root:Batch:       1 transpose9_0                   0.00201192
# INFO:root:Batch:       1 flatten13_0                    0.00201192
# INFO:root:Batch:       1 pool10_output                  0.0028281
# INFO:root:Batch:       1 pool10_cls_pred_conv_output    0.000600271
# INFO:root:Batch:       1 transpose11_0                  0.000600271
# INFO:root:Batch:       1 flatten16_0                    0.000600271
# INFO:root:Batch:       1 concat0_output                 0.710875
# INFO:root:Batch:       1 reshape0_0                     0.710875
# INFO:root:Batch:       1 multibox_cls_pred_0            0.710875
# INFO:root:Batch:       1 relu4_3_anchors_output         0.578537
# INFO:root:Batch:       1 flatten2_0                     0.578537
# INFO:root:Batch:       1 relu7_anchors_output           0.582957
# INFO:root:Batch:       1 flatten5_0                     0.582957
# INFO:root:Batch:       1 relu8_2_anchors_output         0.594703
# INFO:root:Batch:       1 flatten8_0                     0.594703
# INFO:root:Batch:       1 relu9_2_anchors_output         0.610375
# INFO:root:Batch:       1 flatten11_0                    0.610375
# INFO:root:Batch:       1 relu10_2_anchors_output        0.627113
# INFO:root:Batch:       1 flatten14_0                    0.627113
# INFO:root:Batch:       1 pool10_anchors_output          0.663065
# INFO:root:Batch:       1 flatten17_0                    0.663065
# INFO:root:Batch:       1 concat1_output                 0.582306
# INFO:root:Batch:       1 multibox_anchors_0             0.582306
# INFO:root:Batch:       1 multibox_target_loc_target     0.101533
# INFO:root:Batch:       1 multibox_target_loc_mask       0.0343542
# INFO:root:Batch:       1 multibox_target_cls_target     0.394548
# INFO:root:Batch:       1 cls_prob_output                0.0601424
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_output   0.693489
# INFO:root:Batch:       1 transpose0_0                   0.693489
# INFO:root:Batch:       1 flatten0_0                     0.693489
# INFO:root:Batch:       1 relu7_loc_pred_conv_output     1.008
# INFO:root:Batch:       1 transpose2_0                   1.008
# INFO:root:Batch:       1 flatten3_0                     1.008
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_output   0.140336
# INFO:root:Batch:       1 transpose4_0                   0.140336
# INFO:root:Batch:       1 flatten6_0                     0.140336
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_output   0.0203925
# INFO:root:Batch:       1 transpose6_0                   0.0203925
# INFO:root:Batch:       1 flatten9_0                     0.0203925
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_output  0.00242364
# INFO:root:Batch:       1 transpose8_0                   0.00242364
# INFO:root:Batch:       1 flatten12_0                    0.00242364
# INFO:root:Batch:       1 pool10_loc_pred_conv_output    0.00081078
# INFO:root:Batch:       1 transpose10_0                  0.00081078
# INFO:root:Batch:       1 flatten15_0                    0.00081078
# INFO:root:Batch:       1 multibox_loc_pred_output       0.766716
# INFO:root:Batch:       1 _minus0_0                      0.773378
# INFO:root:Batch:       1 _mul0_0                        0.104671
# INFO:root:Batch:       1 loc_loss__0                    0.0950156
# INFO:root:Batch:       1 loc_loss_output                0.0950156
# INFO:root:Batch:       1 cls_label_output               0.394548
# INFO:root:Batch:       1 conv1_1_output                 64.1294
# INFO:root:Batch:       1 relu1_1_output                 45.4042
# INFO:root:Batch:       1 conv1_2_output                 220.592
# INFO:root:Batch:       1 relu1_2_output                 193.343
# INFO:root:Batch:       1 pool1_output                   246.255
# INFO:root:Batch:       1 conv2_1_output                 447.201
# INFO:root:Batch:       1 relu2_1_output                 315.777
# INFO:root:Batch:       1 conv2_2_output                 686.996
# INFO:root:Batch:       1 relu2_2_output                 456.6
# INFO:root:Batch:       1 pool2_output                   645.691
# INFO:root:Batch:       1 conv3_1_output                 875.194
# INFO:root:Batch:       1 relu3_1_output                 525.704
# INFO:root:Batch:       1 conv3_2_output                 896.191
# INFO:root:Batch:       1 relu3_2_output                 544.249
# INFO:root:Batch:       1 conv3_3_output                 905.532
# INFO:root:Batch:       1 relu3_3_output                 482.832
# INFO:root:Batch:       1 pool3_output                   693.996
# INFO:root:Batch:       1 conv4_1_output                 869.6
# INFO:root:Batch:       1 relu4_1_output                 366.04
# INFO:root:Batch:       1 conv4_2_output                 594.399
# INFO:root:Batch:       1 relu4_2_output                 215.195
# INFO:root:Batch:       1 conv4_3_output                 399.313
# INFO:root:Batch:       1 relu4_3_output                 84.3167
# INFO:root:Batch:       1 relu4_3_norm_output            0.0441941
# INFO:root:Batch:       1 relu4_3_norm_norm              1907.87
# INFO:root:Batch:       1 broadcast_mul0_0               0.0441941
# INFO:root:Batch:       1 _mulscalar0_0                  0.883882
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_output   0.664477
# INFO:root:Batch:       1 transpose1_0                   0.664477
# INFO:root:Batch:       1 flatten1_0                     0.664477
# INFO:root:Batch:       1 pool4_output                   129.095
# INFO:root:Batch:       1 conv5_1_output                 194.216
# INFO:root:Batch:       1 relu5_1_output                 63.5215
# INFO:root:Batch:       1 conv5_2_output                 109.178
# INFO:root:Batch:       1 relu5_2_output                 29.2078
# INFO:root:Batch:       1 conv5_3_output                 67.133
# INFO:root:Batch:       1 relu5_3_output                 7.69098
# INFO:root:Batch:       1 pool5_output                   14.0696
# INFO:root:Batch:       1 conv6_output                   5.51923
# INFO:root:Batch:       1 relu6_output                   3.91532
# INFO:root:Batch:       1 conv7_output                   2.247
# INFO:root:Batch:       1 relu7_output                   1.52178
# INFO:root:Batch:       1 relu7_cls_pred_conv_output     1.17451
# INFO:root:Batch:       1 transpose3_0                   1.17451
# INFO:root:Batch:       1 flatten4_0                     1.17451
# INFO:root:Batch:       1 conv8_1_output                 1.08853
# INFO:root:Batch:       1 relu8_1_output                 0.755557
# INFO:root:Batch:       1 conv8_2_output                 0.339962
# INFO:root:Batch:       1 relu8_2_output                 0.23834
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_output   0.160124
# INFO:root:Batch:       1 transpose5_0                   0.160124
# INFO:root:Batch:       1 flatten7_0                     0.160124
# INFO:root:Batch:       1 conv9_1_output                 0.176833
# INFO:root:Batch:       1 relu9_1_output                 0.124699
# INFO:root:Batch:       1 conv9_2_output                 0.0582245
# INFO:root:Batch:       1 relu9_2_output                 0.0394666
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_output   0.0219238
# INFO:root:Batch:       1 transpose7_0                   0.0219238
# INFO:root:Batch:       1 flatten10_0                    0.0219238
# INFO:root:Batch:       1 conv10_1_output                0.0237304
# INFO:root:Batch:       1 relu10_1_output                0.0178174
# INFO:root:Batch:       1 conv10_2_output                0.0069054
# INFO:root:Batch:       1 relu10_2_output                0.004926
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_output  0.00275224
# INFO:root:Batch:       1 transpose9_0                   0.00275224
# INFO:root:Batch:       1 flatten13_0                    0.00275224
# INFO:root:Batch:       1 pool10_output                  0.00374091
# INFO:root:Batch:       1 pool10_cls_pred_conv_output    0.000791524
# INFO:root:Batch:       1 transpose11_0                  0.000791524
# INFO:root:Batch:       1 flatten16_0                    0.000791524
# INFO:root:Batch:       1 concat0_output                 0.820182
# INFO:root:Batch:       1 reshape0_0                     0.820182
# INFO:root:Batch:       1 multibox_cls_pred_0            0.820182
# INFO:root:Batch:       1 relu4_3_anchors_output         0.578537
# INFO:root:Batch:       1 flatten2_0                     0.578537
# INFO:root:Batch:       1 relu7_anchors_output           0.582957
# INFO:root:Batch:       1 flatten5_0                     0.582957
# INFO:root:Batch:       1 relu8_2_anchors_output         0.594703
# INFO:root:Batch:       1 flatten8_0                     0.594703
# INFO:root:Batch:       1 relu9_2_anchors_output         0.610375
# INFO:root:Batch:       1 flatten11_0                    0.610375
# INFO:root:Batch:       1 relu10_2_anchors_output        0.627113
# INFO:root:Batch:       1 flatten14_0                    0.627113
# INFO:root:Batch:       1 pool10_anchors_output          0.663065
# INFO:root:Batch:       1 flatten17_0                    0.663065
# INFO:root:Batch:       1 concat1_output                 0.582306
# INFO:root:Batch:       1 multibox_anchors_0             0.582306
# INFO:root:Batch:       1 multibox_target_loc_target     0.0257458
# INFO:root:Batch:       1 multibox_target_loc_mask       0.0189525
# INFO:root:Batch:       1 multibox_target_cls_target     0.226261
# INFO:root:Batch:       1 cls_prob_output                0.0639689
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_output   0.703248
# INFO:root:Batch:       1 transpose0_0                   0.703248
# INFO:root:Batch:       1 flatten0_0                     0.703248
# INFO:root:Batch:       1 relu7_loc_pred_conv_output     1.3228
# INFO:root:Batch:       1 transpose2_0                   1.3228
# INFO:root:Batch:       1 flatten3_0                     1.3228
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_output   0.17794
# INFO:root:Batch:       1 transpose4_0                   0.17794
# INFO:root:Batch:       1 flatten6_0                     0.17794
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_output   0.0263428
# INFO:root:Batch:       1 transpose6_0                   0.0263428
# INFO:root:Batch:       1 flatten9_0                     0.0263428
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_output  0.00320096
# INFO:root:Batch:       1 transpose8_0                   0.00320096
# INFO:root:Batch:       1 flatten12_0                    0.00320096
# INFO:root:Batch:       1 pool10_loc_pred_conv_output    0.00109315
# INFO:root:Batch:       1 transpose10_0                  0.00109315
# INFO:root:Batch:       1 flatten15_0                    0.00109315
# INFO:root:Batch:       1 multibox_loc_pred_output       0.902435
# INFO:root:Batch:       1 _minus0_0                      0.902853
# INFO:root:Batch:       1 _mul0_0                        0.0325522
# INFO:root:Batch:       1 loc_loss__0                    0.0264722
# INFO:root:Batch:       1 loc_loss_output                0.0264722
# INFO:root:Batch:       1 cls_label_output               0.226261
# INFO:root:Batch:       1 loc_loss_backward_data         0.0192303
# INFO:root:Batch:       1 loc_loss__backward_0           0.000175634
# INFO:root:Batch:       1 _mul0_backward_0               0.00777206
# INFO:root:Batch:       1 _mul0_backward_1               0.000175634
# INFO:root:Batch:       1 _minus0_backward_0             0.000175634
# INFO:root:Batch:       1 _minus0_backward_1             0.0149117
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg0 7.51e-05
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg1 0.000182216
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg2 0.000267932
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg3 0.00059138
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg4 0.0
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg5 0.00236469
# INFO:root:Batch:       1 flatten0_backward_0            7.51e-05
# INFO:root:Batch:       1 transpose0_backward_0          7.51e-05
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_data 9.24695e-06
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_weight 0.0071345
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_bias 0.00807176
# INFO:root:Batch:       1 multibox_target_backward_anchor 0.0
# INFO:root:Batch:       1 multibox_target_backward_label 0.0
# INFO:root:Batch:       1 multibox_target_backward_cls_pred 0.0
# INFO:root:Batch:       1 multibox_anchors_backward_0    0.0
# INFO:root:Batch:       1 concat1_backward_arg0          0.0
# INFO:root:Batch:       1 concat1_backward_arg1          0.0
# INFO:root:Batch:       1 concat1_backward_arg2          0.0
# INFO:root:Batch:       1 concat1_backward_arg3          0.0
# INFO:root:Batch:       1 concat1_backward_arg4          0.0
# INFO:root:Batch:       1 concat1_backward_arg5          0.0
# INFO:root:Batch:       1 flatten2_backward_0            0.0
# INFO:root:Batch:       1 relu4_3_anchors_backward_data  0.0
# INFO:root:Batch:       1 cls_prob_backward_data         1.11039e-05
# INFO:root:Batch:       1 cls_prob_backward_label        0.0
# INFO:root:Batch:       1 sum_grad_0                     1.11039e-05
# INFO:root:Batch:       1 multibox_cls_pred_backward_0   1.11039e-05
# INFO:root:Batch:       1 reshape0_backward_0            1.11039e-05
# INFO:root:Batch:       1 concat0_backward_arg0          1.10288e-05
# INFO:root:Batch:       1 concat0_backward_arg1          1.13245e-05
# INFO:root:Batch:       1 concat0_backward_arg2          1.09005e-05
# INFO:root:Batch:       1 concat0_backward_arg3          1.09277e-05
# INFO:root:Batch:       1 concat0_backward_arg4          1.09275e-05
# INFO:root:Batch:       1 concat0_backward_arg5          1.09277e-05
# INFO:root:Batch:       1 flatten1_backward_0            1.10288e-05
# INFO:root:Batch:       1 transpose1_backward_0          1.10288e-05
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_data 2.93726e-06
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_weight 0.0311867
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_bias 0.12593
# INFO:root:Batch:       1 sum_grad_0                     9.70193e-06
# INFO:root:Batch:       1 _mulscalar0_backward_0         0.000194039
# INFO:root:Batch:       1 broadcast_mul0_backward_0      0.0108041
# INFO:root:Batch:       1 broadcast_mul0_backward_1      0.000194039
# INFO:root:Batch:       1 flatten3_backward_0            0.000182216
# INFO:root:Batch:       1 transpose2_backward_0          0.000182216
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_data 2.25098e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_weight 0.0128346
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_bias 0.0113431
# INFO:root:Batch:       1 flatten5_backward_0            0.0
# INFO:root:Batch:       1 relu7_anchors_backward_data    0.0
# INFO:root:Batch:       1 flatten6_backward_0            0.000267932
# INFO:root:Batch:       1 transpose4_backward_0          0.000267932
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_data 4.43574e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_weight 0.00152505
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_bias 0.00660074
# INFO:root:Batch:       1 flatten8_backward_0            0.0
# INFO:root:Batch:       1 relu8_2_anchors_backward_data  0.0
# INFO:root:Batch:       1 flatten9_backward_0            0.00059138
# INFO:root:Batch:       1 transpose6_backward_0          0.00059138
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_backward_data 0.000134735
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_backward_weight 0.00029569
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_backward_bias 0.00872857
# INFO:root:Batch:       1 flatten11_backward_0           0.0
# INFO:root:Batch:       1 relu9_2_anchors_backward_data  0.0
# INFO:root:Batch:       1 flatten12_backward_0           0.0
# INFO:root:Batch:       1 transpose8_backward_0          0.0
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_backward_data 0.0
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_backward_weight 0.0
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_backward_bias 0.0
# INFO:root:Batch:       1 flatten14_backward_0           0.0
# INFO:root:Batch:       1 relu10_2_anchors_backward_data 0.0
# INFO:root:Batch:       1 flatten15_backward_0           0.00236469
# INFO:root:Batch:       1 transpose10_backward_0         0.00236469
# INFO:root:Batch:       1 pool10_loc_pred_conv_backward_data 0.00018964
# INFO:root:Batch:       1 pool10_loc_pred_conv_backward_weight 1.02174e-05
# INFO:root:Batch:       1 pool10_loc_pred_conv_backward_bias 0.00668674
# INFO:root:Batch:       1 flatten17_backward_0           0.0
# INFO:root:Batch:       1 pool10_anchors_backward_data   0.0
# INFO:root:Batch:       1 flatten16_backward_0           1.09277e-05
# INFO:root:Batch:       1 transpose11_backward_0         1.09277e-05
# INFO:root:Batch:       1 pool10_cls_pred_conv_backward_data 1.66402e-06
# INFO:root:Batch:       1 pool10_cls_pred_conv_backward_weight 9.23996e-08
# INFO:root:Batch:       1 pool10_cls_pred_conv_backward_bias 8.07096e-05
# INFO:root:Batch:       1 sum_grad_0                     0.00018968
# INFO:root:Batch:       1 pool10_backward_data           2.10756e-05
# INFO:root:Batch:       1 flatten13_backward_0           1.09275e-05
# INFO:root:Batch:       1 transpose9_backward_0          1.09275e-05
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_backward_data 3.98325e-06
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_backward_weight 1.906e-06
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_backward_bias 0.000786783
# INFO:root:Batch:       1 sum_grad_0                     2.142e-05
# INFO:root:Batch:       1 relu10_2_backward_data         1.53448e-05
# INFO:root:Batch:       1 conv10_2_backward_data         4.75508e-06
# INFO:root:Batch:       1 conv10_2_backward_weight       4.16385e-06
# INFO:root:Batch:       1 conv10_2_backward_bias         0.000331068
# INFO:root:Batch:       1 relu10_1_backward_data         3.40619e-06
# INFO:root:Batch:       1 conv10_1_backward_data         1.6049e-06
# INFO:root:Batch:       1 conv10_1_backward_weight       4.51636e-06
# INFO:root:Batch:       1 conv10_1_backward_bias         0.000108031
# INFO:root:Batch:       1 flatten10_backward_0           1.09277e-05
# INFO:root:Batch:       1 transpose7_backward_0          1.09277e-05
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_backward_data 4.29634e-06
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_backward_weight 5.36585e-05
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_backward_bias 0.00217982
# INFO:root:Batch:       1 sum_grad_0                     0.000134826
# INFO:root:Batch:       1 relu9_2_backward_data          9.5954e-05
# INFO:root:Batch:       1 conv9_2_backward_data          3.13956e-05
# INFO:root:Batch:       1 conv9_2_backward_weight        0.00016516
# INFO:root:Batch:       1 conv9_2_backward_bias          0.0015294
# INFO:root:Batch:       1 relu9_1_backward_data          2.24389e-05
# INFO:root:Batch:       1 conv9_1_backward_data          8.18244e-06
# INFO:root:Batch:       1 conv9_1_backward_weight        0.000144468
# INFO:root:Batch:       1 conv9_1_backward_bias          0.00068344
# INFO:root:Batch:       1 flatten7_backward_0            1.09005e-05
# INFO:root:Batch:       1 transpose5_backward_0          1.09005e-05
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_backward_data 3.78341e-06
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_backward_weight 0.00140124
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_backward_bias 0.00871182
# INFO:root:Batch:       1 sum_grad_0                     4.53e-05
# INFO:root:Batch:       1 relu8_2_backward_data          3.16771e-05
# INFO:root:Batch:       1 conv8_2_backward_data          1.0584e-05
# INFO:root:Batch:       1 conv8_2_backward_weight        0.00105401
# INFO:root:Batch:       1 conv8_2_backward_bias          0.00184434
# INFO:root:Batch:       1 relu8_1_backward_data          7.48663e-06
# INFO:root:Batch:       1 conv8_1_backward_data          2.72513e-06
# INFO:root:Batch:       1 conv8_1_backward_weight        0.00087622
# INFO:root:Batch:       1 conv8_1_backward_bias          0.000746811
# INFO:root:Batch:       1 flatten4_backward_0            1.13245e-05
# INFO:root:Batch:       1 transpose3_backward_0          1.13245e-05
# INFO:root:Batch:       1 relu7_cls_pred_conv_backward_data 2.89914e-06
# INFO:root:Batch:       1 relu7_cls_pred_conv_backward_weight 0.0304175
# INFO:root:Batch:       1 relu7_cls_pred_conv_backward_bias 0.0319053
# INFO:root:Batch:       1 sum_grad_0                     2.28591e-05
# INFO:root:Batch:       1 relu7_backward_data            1.57476e-05
# INFO:root:Batch:       1 conv7_backward_data            9.05834e-06
# INFO:root:Batch:       1 conv7_backward_weight          0.00975481
# INFO:root:Batch:       1 conv7_backward_bias            0.00435652
# INFO:root:Batch:       1 relu6_backward_data            6.45746e-06
# INFO:root:Batch:       1 conv6_backward_data            3.66672e-06
# INFO:root:Batch:       1 conv6_backward_weight          0.00525579
# INFO:root:Batch:       1 conv6_backward_bias            0.00131261
# INFO:root:Batch:       1 pool5_backward_data            1.04144e-05
# INFO:root:Batch:       1 relu5_3_backward_data          1.44991e-06
# INFO:root:Batch:       1 conv5_3_backward_data          8.65591e-07
# INFO:root:Batch:       1 conv5_3_backward_weight        0.00266779
# INFO:root:Batch:       1 conv5_3_backward_bias          0.000152372
# INFO:root:Batch:       1 relu5_2_backward_data          3.92888e-07
# INFO:root:Batch:       1 conv5_2_backward_data          3.82146e-07
# INFO:root:Batch:       1 conv5_2_backward_weight        0.00312215
# INFO:root:Batch:       1 conv5_2_backward_bias          9.55166e-05
# INFO:root:Batch:       1 relu5_1_backward_data          1.93382e-07
# INFO:root:Batch:       1 conv5_1_backward_data          1.98377e-07
# INFO:root:Batch:       1 conv5_1_backward_weight        0.00363821
# INFO:root:Batch:       1 conv5_1_backward_bias          5.61677e-05
# INFO:root:Batch:       1 pool4_backward_data            1.80661e-07
# INFO:root:Batch:       1 relu4_3_norm_backward_data     3.13518e-07
# INFO:root:Batch:       1 sum_grad_0                     3.62086e-07
# INFO:root:Batch:       1 relu4_3_backward_data          8.69379e-08
# INFO:root:Batch:       1 conv4_3_backward_data          7.12775e-08
# INFO:root:Batch:       1 conv4_3_backward_weight        0.00546858
# INFO:root:Batch:       1 conv4_3_backward_bias          0.000201492
# INFO:root:Batch:       1 relu4_2_backward_data          4.03099e-08
# INFO:root:Batch:       1 conv4_2_backward_data          4.54708e-08
# INFO:root:Batch:       1 conv4_2_backward_weight        0.00414384
# INFO:root:Batch:       1 conv4_2_backward_bias          8.88087e-05
# INFO:root:Batch:       1 relu4_1_backward_data          2.95912e-08
# INFO:root:Batch:       1 conv4_1_backward_data          6.12548e-08
# INFO:root:Batch:       1 conv4_1_backward_weight        0.00523038
# INFO:root:Batch:       1 conv4_1_backward_bias          7.24601e-05
# INFO:root:Batch:       1 pool3_backward_data            5.92977e-08
# INFO:root:Batch:       1 relu3_3_backward_data          2.06571e-08
# INFO:root:Batch:       1 conv3_3_backward_data          2.47101e-08
# INFO:root:Batch:       1 conv3_3_backward_weight        0.00806828
# INFO:root:Batch:       1 conv3_3_backward_bias          0.000182974
# INFO:root:Batch:       1 relu3_2_backward_data          1.85879e-08
# INFO:root:Batch:       1 conv3_2_backward_data          3.45627e-08
# INFO:root:Batch:       1 conv3_2_backward_weight        0.00792536
# INFO:root:Batch:       1 conv3_2_backward_bias          0.000178415
# INFO:root:Batch:       1 relu3_1_backward_data          2.93632e-08
# INFO:root:Batch:       1 conv3_1_backward_data          0.0445123
# INFO:root:Batch:       1 conv3_1_backward_weight        0.0130166
# INFO:root:Batch:       1 conv3_1_backward_bias          0.00029199
# INFO:root:Batch:       1 loc_loss_backward_data         0.0178569
# INFO:root:Batch:       1 loc_loss__backward_0           0.000178145
# INFO:root:Batch:       1 _mul0_backward_0               0.0115366
# INFO:root:Batch:       1 _mul0_backward_1               0.000178145
# INFO:root:Batch:       1 _minus0_backward_0             0.000178145
# INFO:root:Batch:       1 _minus0_backward_1             0.0154746
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg0 8.3074e-05
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg1 0.000210541
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg2 0.000260729
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg3 0.000485141
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg4 0.000494256
# INFO:root:Batch:       1 multibox_loc_pred_backward_arg5 0.00166984
# INFO:root:Batch:       1 flatten0_backward_0            8.3074e-05
# INFO:root:Batch:       1 transpose0_backward_0          8.3074e-05
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_data 1.01256e-05
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_weight 0.00789203
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_backward_bias 0.00892881
# INFO:root:Batch:       1 multibox_target_backward_anchor 0.0
# INFO:root:Batch:       1 multibox_target_backward_label inf
# INFO:root:Batch:       1 multibox_target_backward_cls_pred 0.0
# INFO:root:Batch:       1 multibox_anchors_backward_0    0.0
# INFO:root:Batch:       1 concat1_backward_arg0          0.0
# INFO:root:Batch:       1 concat1_backward_arg1          0.0
# INFO:root:Batch:       1 concat1_backward_arg2          0.0
# INFO:root:Batch:       1 concat1_backward_arg3          0.0
# INFO:root:Batch:       1 concat1_backward_arg4          0.0
# INFO:root:Batch:       1 concat1_backward_arg5          0.0
# INFO:root:Batch:       1 flatten2_backward_0            0.0
# INFO:root:Batch:       1 relu4_3_anchors_backward_data  0.0
# INFO:root:Batch:       1 cls_prob_backward_data         1.10304e-05
# INFO:root:Batch:       1 cls_prob_backward_label        0.0
# INFO:root:Batch:       1 sum_grad_0                     1.10304e-05
# INFO:root:Batch:       1 multibox_cls_pred_backward_0   1.10304e-05
# INFO:root:Batch:       1 reshape0_backward_0            1.10304e-05
# INFO:root:Batch:       1 concat0_backward_arg0          1.09995e-05
# INFO:root:Batch:       1 concat0_backward_arg1          1.1135e-05
# INFO:root:Batch:       1 concat0_backward_arg2          1.09089e-05
# INFO:root:Batch:       1 concat0_backward_arg3          1.09277e-05
# INFO:root:Batch:       1 concat0_backward_arg4          1.09276e-05
# INFO:root:Batch:       1 concat0_backward_arg5          1.09277e-05
# INFO:root:Batch:       1 flatten1_backward_0            1.09995e-05
# INFO:root:Batch:       1 transpose1_backward_0          1.09995e-05
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_data 2.93245e-06
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_weight 0.0357431
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_backward_bias 0.125588
# INFO:root:Batch:       1 sum_grad_0                     1.05421e-05
# INFO:root:Batch:       1 _mulscalar0_backward_0         0.000210842
# INFO:root:Batch:       1 broadcast_mul0_backward_0      0.0123037
# INFO:root:Batch:       1 broadcast_mul0_backward_1      0.000210842
# INFO:root:Batch:       1 flatten3_backward_0            0.000210541
# INFO:root:Batch:       1 transpose2_backward_0          0.000210541
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_data 2.59277e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_weight 0.0140919
# INFO:root:Batch:       1 relu7_loc_pred_conv_backward_bias 0.0144494
# INFO:root:Batch:       1 flatten5_backward_0            0.0
# INFO:root:Batch:       1 relu7_anchors_backward_data    0.0
# INFO:root:Batch:       1 flatten6_backward_0            0.000260729
# INFO:root:Batch:       1 transpose4_backward_0          0.000260729
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_data 4.52642e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_weight 0.00138891
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_backward_bias 0.00737453
# INFO:root:Batch:       1 flatten8_backward_0            0.0
# INFO:root:Batch:       1 relu8_2_anchors_backward_data  0.0
# INFO:root:Batch:       1 flatten9_backward_0            0.000485141
# ...
# INFO:root:Batch:       1 conv9_1_bias                   1.15027e-06
# INFO:root:Batch:       1 conv9_2_weight                 0.013889
# INFO:root:Batch:       1 conv9_2_bias                   2.77815e-06
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_weight   0.0139336
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_bias     8.72127e-06
# INFO:root:Batch:       1 conv10_1_weight                0.0415847
# INFO:root:Batch:       1 conv10_1_bias                  2.62958e-07
# INFO:root:Batch:       1 conv10_2_weight                0.013887
# INFO:root:Batch:       1 conv10_2_bias                  7.9964e-07
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_weight  0.0139278
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_bias    3.13952e-06
# INFO:root:Batch:       1 pool10_cls_pred_conv_weight    0.0139251
# INFO:root:Batch:       1 pool10_cls_pred_conv_bias      3.3684e-07
# INFO:root:Batch:       1 label                          1.24907
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_weight   0.0118912
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_bias     4.91479e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_weight     0.00841644
# INFO:root:Batch:       1 relu7_loc_pred_conv_bias       3.91212e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_weight   0.0117526
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_bias     1.06421e-05
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_weight   0.0163245
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_bias     1.17981e-05
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_weight  0.0162178
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_bias    3.00848e-06
# INFO:root:Batch:       1 pool10_loc_pred_conv_weight    0.016296
# INFO:root:Batch:       1 pool10_loc_pred_conv_bias      9.77295e-06
# INFO:root:Batch:       1 relu4_3_scale                  0.999995
# INFO:root:Batch:       1 data                           54.4033
# INFO:root:Batch:       1 conv1_1_weight                 0.206714
# INFO:root:Batch:       1 conv1_1_bias                   0.59941
# INFO:root:Batch:       1 conv1_2_weight                 0.042761
# INFO:root:Batch:       1 conv1_2_bias                   0.339866
# INFO:root:Batch:       1 conv2_1_weight                 0.0322237
# INFO:root:Batch:       1 conv2_1_bias                   0.164859
# INFO:root:Batch:       1 conv2_2_weight                 0.0235423
# INFO:root:Batch:       1 conv2_2_bias                   0.189587
# INFO:root:Batch:       1 conv3_1_weight                 0.0173759
# INFO:root:Batch:       1 conv3_1_bias                   0.0727676
# INFO:root:Batch:       1 conv3_2_weight                 0.012347
# INFO:root:Batch:       1 conv3_2_bias                   0.0842335
# INFO:root:Batch:       1 conv3_3_weight                 0.0126857
# INFO:root:Batch:       1 conv3_3_bias                   0.0872849
# INFO:root:Batch:       1 conv4_1_weight                 0.0100613
# INFO:root:Batch:       1 conv4_1_bias                   0.0574756
# INFO:root:Batch:       1 conv4_2_weight                 0.00763843
# INFO:root:Batch:       1 conv4_2_bias                   0.0532511
# INFO:root:Batch:       1 conv4_3_weight                 0.00799655
# INFO:root:Batch:       1 conv4_3_bias                   0.075195
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_weight   0.01135
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_bias     0.000503794
# INFO:root:Batch:       1 conv5_1_weight                 0.00871323
# INFO:root:Batch:       1 conv5_1_bias                   0.139061
# INFO:root:Batch:       1 conv5_2_weight                 0.00879156
# INFO:root:Batch:       1 conv5_2_bias                   0.218646
# INFO:root:Batch:       1 conv5_3_weight                 0.00854689
# INFO:root:Batch:       1 conv5_3_bias                   0.515104
# INFO:root:Batch:       1 conv6_weight                   0.00694555
# INFO:root:Batch:       1 conv6_bias                     5.05534e-06
# INFO:root:Batch:       1 conv7_weight                   0.0180354
# INFO:root:Batch:       1 conv7_bias                     1.70707e-05
# INFO:root:Batch:       1 relu7_cls_pred_conv_weight     0.00802357
# INFO:root:Batch:       1 relu7_cls_pred_conv_bias       0.000127269
# INFO:root:Batch:       1 conv8_1_weight                 0.0227836
# INFO:root:Batch:       1 conv8_1_bias                   2.52303e-06
# INFO:root:Batch:       1 conv8_2_weight                 0.00981963
# INFO:root:Batch:       1 conv8_2_bias                   6.64378e-06
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_weight   0.0107712
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_bias     3.48461e-05
# INFO:root:Batch:       1 conv9_1_weight                 0.0322234
# INFO:root:Batch:       1 conv9_1_bias                   1.15027e-06
# INFO:root:Batch:       1 conv9_2_weight                 0.013889
# INFO:root:Batch:       1 conv9_2_bias                   2.77815e-06
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_weight   0.0139336
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_bias     8.72127e-06
# INFO:root:Batch:       1 conv10_1_weight                0.0415847
# INFO:root:Batch:       1 conv10_1_bias                  2.62958e-07
# INFO:root:Batch:       1 conv10_2_weight                0.013887
# INFO:root:Batch:       1 conv10_2_bias                  7.9964e-07
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_weight  0.0139278
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_bias    3.13952e-06
# INFO:root:Batch:       1 pool10_cls_pred_conv_weight    0.0139251
# INFO:root:Batch:       1 pool10_cls_pred_conv_bias      3.3684e-07
# INFO:root:Batch:       1 label                          1.46815
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_weight   0.0118912
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_bias     4.91479e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_weight     0.00841644
# INFO:root:Batch:       1 relu7_loc_pred_conv_bias       3.91212e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_weight   0.0117526
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_bias     1.06421e-05
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_weight   0.0163245
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_bias     1.17981e-05
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_weight  0.0162178
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_bias    3.00848e-06
# INFO:root:Batch:       1 pool10_loc_pred_conv_weight    0.016296
# INFO:root:Batch:       1 pool10_loc_pred_conv_bias      9.77295e-06
# INFO:root:Batch:       1 relu4_3_scale                  0.999995
# INFO:root:Batch:       1 data                           60.2644
# INFO:root:Batch:       1 conv1_1_weight                 0.206714
# INFO:root:Batch:       1 conv1_1_bias                   0.59941
# INFO:root:Batch:       1 conv1_2_weight                 0.042761
# INFO:root:Batch:       1 conv1_2_bias                   0.339866
# INFO:root:Batch:       1 conv2_1_weight                 0.0322237
# INFO:root:Batch:       1 conv2_1_bias                   0.164859
# INFO:root:Batch:       1 conv2_2_weight                 0.0235423
# INFO:root:Batch:       1 conv2_2_bias                   0.189587
# INFO:root:Batch:       1 conv3_1_weight                 0.0173759
# INFO:root:Batch:       1 conv3_1_bias                   0.0727676
# INFO:root:Batch:       1 conv3_2_weight                 0.012347
# INFO:root:Batch:       1 conv3_2_bias                   0.0842335
# INFO:root:Batch:       1 conv3_3_weight                 0.0126857
# INFO:root:Batch:       1 conv3_3_bias                   0.0872849
# INFO:root:Batch:       1 conv4_1_weight                 0.0100613
# INFO:root:Batch:       1 conv4_1_bias                   0.0574756
# INFO:root:Batch:       1 conv4_2_weight                 0.00763843
# INFO:root:Batch:       1 conv4_2_bias                   0.0532511
# INFO:root:Batch:       1 conv4_3_weight                 0.00799655
# INFO:root:Batch:       1 conv4_3_bias                   0.075195
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_weight   0.01135
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_bias     0.000503794
# INFO:root:Batch:       1 conv5_1_weight                 0.00871323
# INFO:root:Batch:       1 conv5_1_bias                   0.139061
# INFO:root:Batch:       1 conv5_2_weight                 0.00879156
# INFO:root:Batch:       1 conv5_2_bias                   0.218646
# INFO:root:Batch:       1 conv5_3_weight                 0.00854689
# INFO:root:Batch:       1 conv5_3_bias                   0.515104
# INFO:root:Batch:       1 conv6_weight                   0.00694555
# INFO:root:Batch:       1 conv6_bias                     5.05534e-06
# INFO:root:Batch:       1 conv7_weight                   0.0180354
# INFO:root:Batch:       1 conv7_bias                     1.70707e-05
# INFO:root:Batch:       1 relu7_cls_pred_conv_weight     0.00802357
# INFO:root:Batch:       1 relu7_cls_pred_conv_bias       0.000127269
# INFO:root:Batch:       1 conv8_1_weight                 0.0227836
# INFO:root:Batch:       1 conv8_1_bias                   2.52303e-06
# INFO:root:Batch:       1 conv8_2_weight                 0.00981963
# INFO:root:Batch:       1 conv8_2_bias                   6.64378e-06
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_weight   0.0107712
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_bias     3.48461e-05
# INFO:root:Batch:       1 conv9_1_weight                 0.0322234
# INFO:root:Batch:       1 conv9_1_bias                   1.15027e-06
# INFO:root:Batch:       1 conv9_2_weight                 0.013889
# INFO:root:Batch:       1 conv9_2_bias                   2.77815e-06
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_weight   0.0139336
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_bias     8.72127e-06
# INFO:root:Batch:       1 conv10_1_weight                0.0415847
# INFO:root:Batch:       1 conv10_1_bias                  2.62958e-07
# INFO:root:Batch:       1 conv10_2_weight                0.013887
# INFO:root:Batch:       1 conv10_2_bias                  7.9964e-07
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_weight  0.0139278
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_bias    3.13952e-06
# INFO:root:Batch:       1 pool10_cls_pred_conv_weight    0.0139251
# INFO:root:Batch:       1 pool10_cls_pred_conv_bias      3.3684e-07
# INFO:root:Batch:       1 label                          2.08627
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_weight   0.0118912
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_bias     4.91479e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_weight     0.00841644
# INFO:root:Batch:       1 relu7_loc_pred_conv_bias       3.91212e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_weight   0.0117526
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_bias     1.06421e-05
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_weight   0.0163245
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_bias     1.17981e-05
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_weight  0.0162178
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_bias    3.00848e-06
# INFO:root:Batch:       1 pool10_loc_pred_conv_weight    0.016296
# INFO:root:Batch:       1 pool10_loc_pred_conv_bias      9.77295e-06
# INFO:root:Batch:       1 relu4_3_scale                  0.999995
# INFO:root:Batch:       1 data                           62.9786
# INFO:root:Batch:       1 conv1_1_weight                 0.206714
# INFO:root:Batch:       1 conv1_1_bias                   0.59941
# INFO:root:Batch:       1 conv1_2_weight                 0.042761
# INFO:root:Batch:       1 conv1_2_bias                   0.339866
# INFO:root:Batch:       1 conv2_1_weight                 0.0322237
# INFO:root:Batch:       1 conv2_1_bias                   0.164859
# INFO:root:Batch:       1 conv2_2_weight                 0.0235423
# INFO:root:Batch:       1 conv2_2_bias                   0.189587
# INFO:root:Batch:       1 conv3_1_weight                 0.0173759
# INFO:root:Batch:       1 conv3_1_bias                   0.0727676
# INFO:root:Batch:       1 conv3_2_weight                 0.012347
# INFO:root:Batch:       1 conv3_2_bias                   0.0842335
# INFO:root:Batch:       1 conv3_3_weight                 0.0126857
# INFO:root:Batch:       1 conv3_3_bias                   0.0872849
# INFO:root:Batch:       1 conv4_1_weight                 0.0100613
# INFO:root:Batch:       1 conv4_1_bias                   0.0574756
# INFO:root:Batch:       1 conv4_2_weight                 0.00763843
# INFO:root:Batch:       1 conv4_2_bias                   0.0532511
# INFO:root:Batch:       1 conv4_3_weight                 0.00799655
# INFO:root:Batch:       1 conv4_3_bias                   0.075195
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_weight   0.01135
# INFO:root:Batch:       1 relu4_3_cls_pred_conv_bias     0.000503794
# INFO:root:Batch:       1 conv5_1_weight                 0.00871323
# INFO:root:Batch:       1 conv5_1_bias                   0.139061
# INFO:root:Batch:       1 conv5_2_weight                 0.00879156
# INFO:root:Batch:       1 conv5_2_bias                   0.218646
# INFO:root:Batch:       1 conv5_3_weight                 0.00854689
# INFO:root:Batch:       1 conv5_3_bias                   0.515104
# INFO:root:Batch:       1 conv6_weight                   0.00694555
# INFO:root:Batch:       1 conv6_bias                     5.05534e-06
# INFO:root:Batch:       1 conv7_weight                   0.0180354
# INFO:root:Batch:       1 conv7_bias                     1.70707e-05
# INFO:root:Batch:       1 relu7_cls_pred_conv_weight     0.00802357
# INFO:root:Batch:       1 relu7_cls_pred_conv_bias       0.000127269
# INFO:root:Batch:       1 conv8_1_weight                 0.0227836
# INFO:root:Batch:       1 conv8_1_bias                   2.52303e-06
# INFO:root:Batch:       1 conv8_2_weight                 0.00981963
# INFO:root:Batch:       1 conv8_2_bias                   6.64378e-06
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_weight   0.0107712
# INFO:root:Batch:       1 relu8_2_cls_pred_conv_bias     3.48461e-05
# INFO:root:Batch:       1 conv9_1_weight                 0.0322234
# INFO:root:Batch:       1 conv9_1_bias                   1.15027e-06
# INFO:root:Batch:       1 conv9_2_weight                 0.013889
# INFO:root:Batch:       1 conv9_2_bias                   2.77815e-06
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_weight   0.0139336
# INFO:root:Batch:       1 relu9_2_cls_pred_conv_bias     8.72127e-06
# INFO:root:Batch:       1 conv10_1_weight                0.0415847
# INFO:root:Batch:       1 conv10_1_bias                  2.62958e-07
# INFO:root:Batch:       1 conv10_2_weight                0.013887
# INFO:root:Batch:       1 conv10_2_bias                  7.9964e-07
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_weight  0.0139278
# INFO:root:Batch:       1 relu10_2_cls_pred_conv_bias    3.13952e-06
# INFO:root:Batch:       1 pool10_cls_pred_conv_weight    0.0139251
# INFO:root:Batch:       1 pool10_cls_pred_conv_bias      3.3684e-07
# INFO:root:Batch:       1 label                          1.44919
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_weight   0.0118912
# INFO:root:Batch:       1 relu4_3_loc_pred_conv_bias     4.91479e-05
# INFO:root:Batch:       1 relu7_loc_pred_conv_weight     0.00841644
# INFO:root:Batch:       1 relu7_loc_pred_conv_bias       3.91212e-05
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_weight   0.0117526
# INFO:root:Batch:       1 relu8_2_loc_pred_conv_bias     1.06421e-05
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_weight   0.0163245
# INFO:root:Batch:       1 relu9_2_loc_pred_conv_bias     1.17981e-05
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_weight  0.0162178
# INFO:root:Batch:       1 relu10_2_loc_pred_conv_bias    3.00848e-06
# INFO:root:Batch:       1 pool10_loc_pred_conv_weight    0.016296
# INFO:root:Batch:       1 pool10_loc_pred_conv_bias      9.77295e-06
# %%%%%%%%%%%%%%%%%%%%%% ITER Data Loaded %%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%% ITER Data Loaded %%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%% ITER Data Loaded %%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%% ITER Data Loaded %%%%%%%%%%%%%%%%%%%
